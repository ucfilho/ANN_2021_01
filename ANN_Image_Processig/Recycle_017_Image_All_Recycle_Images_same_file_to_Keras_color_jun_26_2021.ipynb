# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/ANN_2021_01/blob/main/ANN_Image_Processig/Recycle_017_Image_All_Recycle_Images_same_file_to_Keras_color_jun_26_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import cv2
import random
import zipfile
from sklearn.model_selection import train_test_split

# %%
# !git clone https://github.com/ucfilho/ANN_2021_01/
# %cd ANN_2021_01
# Out:
# fatal: destination path 'ANN_2021_01' already exists and is not an empty directory.
# /content/ANN_2021_01

# %%
# all images are load in variable x...
Arq =['cardboard.zip','glass.zip','metal.zip','not_recycle.zip',
      'paper.zip','plastic.zip']

img_name=[]
x_gray=[]
x_original = []
for FILE in Arq:
  file_name = zipfile.ZipFile(FILE, 'r')
  file_name.extractall()
  with zipfile.ZipFile(FILE, "r") as f:
      for name in f.namelist():
          img_name.append(name)

# %%
y_names = []
for yy in img_name:
  name = yy[0]+yy[1]+yy[2]
  y_names.append(name)

# %%
unique_list = []    
for yy in y_names:
  if yy not in unique_list:
    unique_list.append(yy)

# %%
n = len(unique_list)
y = []
for yy in y_names:
  for i in range(n):
    if(yy == unique_list[i]):
      y.append(i)

# %%
DATASET_SIZE = len(y_names)
Ind = range(DATASET_SIZE)
Img_Size = 80
num_range = DATASET_SIZE

# %%
Ind_train, Ind_test= train_test_split(Ind,test_size=0.20, shuffle=True, random_state=3)

# %%
X_train = []
Y_train = []
for II in Ind_train:
  name = img_name[II]
  X_train.append(cv2.resize(cv2.imread(name),(Img_Size,Img_Size)))
  Y_train.append(y[II])

# %%
X_test= []
Y_test = []
for II in Ind_test:
  name = img_name[II]
  X_test.append(cv2.resize(cv2.imread(name),(Img_Size,Img_Size)))
  Y_test.append(y[II])

# %%
# view some images from the train_ds
num,cols,dim = np.array(X_train[0]).shape
plt.figure(figsize=(16, 16))
for i in range(16):
  ax = plt.subplot(4, 4, i + 1)
  kk = int(random.randrange(num))
  plt.imshow(X_train[kk])
  plt.title(Y_train[kk])
  plt.axis("off")

# %%
# view some images from the train_ds
num,cols,dim = np.array(X_test[0]).shape
plt.figure(figsize=(16, 16))
for i in range(16):
  ax = plt.subplot(4, 4, i + 1)
  kk = int(random.randrange(num))
  plt.imshow(X_test[kk])
  plt.title(Y_test[kk])
  plt.axis("off")
