# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/ANN_2021_01/blob/main/ANN_Image_Processig/Gabarge_001_Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd
import os 
import cv2
import re, random

# %%
# !git clone https://github.com/ucfilho/ANN_2021_01/
# %cd ANN_2021_01
# Out:
# fatal: destination path 'ANN_2021_01' already exists and is not an empty directory.
# /content/ANN_2021_01

# %%
import zipfile
file_name = zipfile.ZipFile('trash.zip', 'r')
file_name.extractall()

# %%
# all images are load in variable x...
FILE='trash.zip'
img_name=[]
x=[]
with zipfile.ZipFile(FILE, "r") as f:
    for name in f.namelist():
        img_name.append(name)
        x.append(cv2.imread(name))
        #x.append(cv2.resize(cv2.imread(name),(64,64)))

# %%
Ind = 6
img=plt.imread(img_name[Ind])
plt.axis("off")
plt.imshow(x[Ind])
plt.title(img_name[Ind])
# Out:
# Text(0.5, 1.0, 'glass7.jpg')

# %%
print(img)
# Out:
# [[[229 195 185]
#   [230 196 186]
#   [230 196 186]
#   ...
#   [184 155 141]
#   [184 155 141]
#   [184 155 141]]
#
#  [[229 195 185]
#   [230 196 186]
#   [230 196 186]
#   ...
#   [185 156 142]
#   [184 155 141]
#   [184 155 141]]
#
#  [[229 195 185]
#   [230 196 186]
#   [230 196 186]
#   ...
#   [185 156 142]
#   [185 156 142]
#   [184 155 141]]
#
#  ...
#
#  [[240 208 195]
#   [240 208 195]
#   [240 208 195]
#   ...
#   [217 187 179]
#   [217 187 179]
#   [217 187 179]]
#
#  [[240 208 195]
#   [240 208 195]
#   [240 208 195]
#   ...
#   [218 188 180]
#   [218 188 180]
#   [218 188 180]]
#
#  [[240 208 195]
#   [240 208 195]
#   [240 208 195]
#   ...
#   [218 188 180]
#   [218 188 180]
#   [219 189 181]]]
